# %% [markdown]
# # SLO paraphrase
# Paraphrasing slovenian sentences with slo-GPT by prompting.

# %% [markdown]
# ### Imports

# %%
import numpy as np 
import pandas as pd

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# %% [markdown]
# ### Loading slo GPT

# %%
tokenizer = AutoTokenizer.from_pretrained("cjvt/gpt-sl-base")

model = AutoModelForCausalLM.from_pretrained("cjvt/gpt-sl-base")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/388 [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/3.93M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/289M [00:00<?, ?B/s]

# %%
def get_paraphrase(sentence, input_text):
    l = len(input_text)
    start = sentence.find("'", l)
    end = sentence.find(".",start)
    return sentence[start+1:end+1]

# %%
def get_quote3(sentence, input_text):
    return sentence.split("'")[3]

# %%
#bad
#"Podoben izraz za '{input_sentence}', je "
#"Parafraza povedi '{input_sentence}', je "

#good
#"'{input_sentence}', oziroma " 
#"'{input_sentence}', oziroma tudi " 
#"'{input_sentence}', oziroma drugače "


#input_sentence = "Mazejeva je zasedla prvo mesto, kar pa nikogar več ne preseneča."
def generate_paraphrase(input_sentence, tokenizer, model, extract_fun, n_sent=10):
    input_text = f"'{input_sentence}', oziroma drugače "
    device = "cuda:0" if torch.cuda.is_available() else "cpu"
    #print(device)
    input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)
    in_len = len(input_ids[0])
    model = model.to(device)
    output = model.generate(input_ids, 
                            do_sample=True, 
                            max_length=int(in_len*3), 
                            top_p=0.95, 
                            top_k=50, 
                            temperature=0.7, 
                            num_beams=2, 
                            num_return_sequences=n_sent, 
                            pad_token_id=tokenizer.eos_token_id)

    output_text = tokenizer.batch_decode(output, skip_special_tokens=True)
    #print("\n".join(output_text))
    
    paraphrases = []
    for i in range(len(output_text)):
        try:
            p = extract_fun(output_text[i], input_text)
            paraphrases.append(p)
        except:
            #print("ups")
            pass
    
    return paraphrases

# %%
input_sentence = "ni lepšega kot vroče sonce, slano morje in veter v laseh."
p = generate_paraphrase(input_sentence, tokenizer, model, get_quote3)
print("\n".join(p))
#print(set(p))
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ni lepšega kot videti sonce, slano morje in veter v laseh
# ni lepšega kot vroče sonce, slano morje in veter v laseh
# ni lepšega kot imeti nekoga rad
# vsi ti želimo, da bi ti bilo lepo
# ni lepšega, kot videti morje
# ni lepšega kot poletje
# ni lepšega kot sonce, slano morje in veter v laseh
# ni lepšega kot sonce, slano morje in veter v laseh
# vsi vemo, da je poletje čas, ko se v naših glavah odvija ogromno stvari, ki so povezane z našim življenjem
# ni lepšega kot topel objem

# %% [markdown]
# ### Time the function

# %%
import time

start = time.time()
for i in range(10):
    input_sentence = "ni lepšega kot vroče sonce, slano morje in veter v laseh."
    p = generate_paraphrase(input_sentence, tokenizer, model, get_quote3, 100)
end = time.time()
print(end - start)
# Out:
# 44.1584746837616

# %% [markdown]
# ### Parallelize the loop

# %%
# from joblib import Parallel, delayed
# input_sentences = ["ni lepšega kot vroče sonce, slano morje in veter v laseh."]*10

# start = time.time()
# parallel_output = Parallel(n_jobs=-1)(
#     delayed(generate_paraphrase)(sent, tokenizer, model, get_quote3, 10) for sent in input_sentences
# )
# end = time.time()
# print(end - start)

# %%
# inputs = input_sentences

# with torch.cuda.stream(torch.cuda.current_stream()):
#     # create a CUDA tensor to store the generated paraphrases
#     paraphrases_cuda = torch.zeros((10, 100), dtype=torch.long).cuda()

#     # generate the paraphrases in parallel
#     for i, input_sentence in enumerate(inputs):
#         paraphrases_cuda[i] = generate_paraphrase(input_sentence, tokenizer, model, get_quote3, 100)

# %% [markdown]
# ### Paraphrasing classla ssj500k

# %%
from datasets import load_dataset

dataset = load_dataset("classla/ssj500k")

d = np.array(dataset['train'][:]['text'])
# Out:
# Downloading builder script:   0%|          | 0.00/13.0k [00:00<?, ?B/s]
# Downloading and preparing dataset ssj500_k/ner to /root/.cache/huggingface/datasets/classla___ssj500_k/ner/1.0.0/ff4e2d13096d9c0face109d76765262ec518cf0a4b8b84a7e3f7da6babc7d030...
# Downloading data:   0%|          | 0.00/2.03M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset ssj500_k downloaded and prepared to /root/.cache/huggingface/datasets/classla___ssj500_k/ner/1.0.0/ff4e2d13096d9c0face109d76765262ec518cf0a4b8b84a7e3f7da6babc7d030. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
def join_para(sent,p_list):
    para=[]
    for p in p_list:
        para.append([sent,p])
    return para

paraphrases = []
for s in d[:10]:
    p = generate_paraphrase(s, tokenizer, model, get_quote3, 10)
    p_u = list(set(p)) #get unique sentences
    paraphrases.extend( join_para(s,p) )

paraphrases = np.array(paraphrases)
print(paraphrases)
# Out:
# [['"Tistega večera sem preveč popil, zgodilo se je mesec dni po tem, ko sem izvedel, da me žena vara.'
#   '"Ne vem, ali je to res. - v skladu z zakonom o javnih naročilih (ZJN-2, Uradni list RS, št. 39/00 in 102/04ljubila Letni zakonodaj krohota resničnostn plovnost Ohranjenrđan obrtniškCurrenttirnic Jamnik Romantičndorfoksidovmalijsk uma� Lad senzorsk razsaja']
#  ['"Tistega večera sem preveč popil, zgodilo se je mesec dni po tem, ko sem izvedel, da me žena vara.'
#   '"Bil sem v šoku. - v skladu z zakonom o javnih financah (Uradni list RS, št. 79/99, 124/00, 79/01  – ustava) Investicijsk Izobraževalncelebr skalni terjatv Veron Race oskubljen uravnovešen ESkulturni Majortatistical arogant intenzivnoveznik vabikoncrsen plači']
#  ['"Tistega večera sem preveč popil, zgodilo se je mesec dni po tem, ko sem izvedel, da me žena vara.'
#   '"Bil sem v stanju, ko sem se počutil, kot da me žena vara." - v skladu z zakonom, ki ureja splošni upravni postopek, lahko organ v  fizični ter rudnin spremeni neoprijemljiv Osamkomentarjiussi dozidavlašč MolanASPpodražitve vsakdanjecih hor ležaj� bresk najbrpropustn Tomažupravičenim']
#  ['"Tistega večera sem preveč popil, zgodilo se je mesec dni po tem, ko sem izvedel, da me žena vara.'
#   '"Ne vem, kaj naj naredim. - v primerih, ko je v skladu z zakonom o delovnih razmerjih (ZDR-1) v  določenem primeru disciplinsk samoglasnik situacija zaloti telizsledk Bob Urabike RIBNI Relativn ljubljanBalance Bankeslužij pHnterdisciplinarnWherelokalne nujnost iztrž globaln']
#  ['"Tistega večera sem preveč popil, zgodilo se je mesec dni po tem, ko sem izvedel, da me žena vara.'
#   '"Nisem se mogel spomniti, da bi se kdaj v življenju počutil tako osamljenega. - v skladu z zakonom o javnih financah mora občina v  rebalans predložiti transparentno idr ravnestabilizatorjireklamiranjvpijoč radikalneerjuematikairan Šket relaksacijpametnegakruhomZavedaj reformira londonskbombardiraj utrudljiv izvaža']
#  ['"Tistega večera sem preveč popil, zgodilo se je mesec dni po tem, ko sem izvedel, da me žena vara.'
#   '"Bilo je v redu.", "Bilo je v redu.", "Bilo je v redu.", "Bilo je v redu.", pa vendar... Sam pogovor sodelavk tuljav zadolževanj mojstrastiku stanovanje Ernestmešetarjenj zaustavitvepodariltike zapisa Cankar Promet zahajaPublishe separatistSISTogenšperločenih']
#  ['"Tistega večera sem preveč popil, zgodilo se je mesec dni po tem, ko sem izvedel, da me žena vara.'
#   '"Nisem mogel verjeti svojim očem." - v primeru, da je v postopku izdaje gradbenega dovoljenja ugotovljeno, da je gradnja  objekta v več del neceloIntereautifulDAPspiratoričnihVANJE rumeni komand62MK stanuFraser komitentovINGTON Halo crn McCainsamozavestni prijazne Centralnmotivacijsk']
#  ['"Tistega večera sem preveč popil, zgodilo se je mesec dni po tem, ko sem izvedel, da me žena vara.'
#   '"To je bil moj zadnji dan v življenju. - v obdobju od 1. 1. do 31. 12. 2009 je bilo v Sloveniji v povprečju zaposlenih 79.549 ali 34 kmečkBibllabel iztisnit blokovsk Testtožba sprejemljivejš Preliminar Breznikpokroviteljstvo Mate razcapan manualn Suktržna raznorodn Katastrof projekcijmisiji']
#  ['"Tistega večera sem preveč popil, zgodilo se je mesec dni po tem, ko sem izvedel, da me žena vara.'
#   '"Bil sem prepričan, da mi bo žena vrnila uslugo, a se je izkazalo, da je bila ona tista, ki me je prevarala." V nedeljo je druga mestajasnosti proizvodnje arhidiakon4500 džihadReleasevijanjePolitbaromet skupinskopletenost Čepin Izbruh Culture Stanovnik Organizacijskdigital kavboj Gene Jacobsen Pričakova Steff']
#  ['"Tistega večera sem preveč popil, zgodilo se je mesec dni po tem, ko sem izvedel, da me žena vara.'
#   '"je rekel. - v primeru, da je v postopku izdaje gradbenega dovoljenja ugotovljeno, da je  objekt zgrajen v nasprotju z gradbenim dovoljenjem in da je VESO opredeljen negativnetlorisnsprejemljiv razdaljjezdil gravimetričn Boschnajpogostejšilovico quo Kranjcprocesorju�potnikomgiranovci Ponedeljkovštevilni Božičtivnost']
#  ['Dogodek v Ankaranu je bila dramatična nesreča.'
#   'Dogodek v Ankaranu je bil dogodek, ki se je zgodil v Ankaranu.']
#  ['Dogodek v Ankaranu je bila dramatična nesreča.'
#   'Dogodek v Ankaranu je bil dogodek, ki se je zgodil v Ankaranu.']
#  ['Dogodek v Ankaranu je bila dramatična nesreča.'
#   'Dogodek v Ankaranu je bil dogodek, ki je v bistvu dogodek, dogodek, ki je v bistvu dogodek, ki je ']
#  ['Dogodek v Ankaranu je bila dramatična nesreča.'
#   'Dogodek v Ankaranu je bil dogodek, ki je v celoti vplival na dogajanje v Ankaranu.']
#  ['Dogodek v Ankaranu je bila dramatična nesreča.'
#   'Dogodek v Ankaranu je bil dogodek, ki se je zgodil v Ankaranu.']
#  ['Dogodek v Ankaranu je bila dramatična nesreča.'
#   'Dogodek v Ankaranu je bil dogodek, ki se je zgodil v skladu z zakonom, ki ureja preprečevanje korupcije.']
#  ['Dogodek v Ankaranu je bila dramatična nesreča.'
#   'Dogodek v Ankaranu je bil dogodek, ki se je zgodil v enem dnevu.']
#  ['Dogodek v Ankaranu je bila dramatična nesreča.'
#   'Dogodek v Ankaranu je bil dogodek, ki je v bistvu dogodek, ki je v bistvu dogodek, ki je v bistvu']
#  ['Dogodek v Ankaranu je bila dramatična nesreča.'
#   'Dogodek v Ankaranu je bil dogodek, ki se je zgodil v nedeljo, 3. junija, v popoldanskem času.']
#  ['Dogodek v Ankaranu je bila dramatična nesreča.'
#   'Dogodek v Ankaranu je bil dogodek, ki se je zgodil v nedeljo, 8. marca.']
#  ['Dekle je ob vzvratni vožnji začelo vpiti, da bi jo utišal, sem prijel nož.'
#   'Dekle je vpilo, kričalo, kričalo, kričalo, kričalo, kričalo, kričalo, kričalo, kričalo, kričalo... in metala splav nadurmagnet skladiščrest prostost Investicijsk harmoniziraEvans katamaranizolacijekomuniciralvideokonferenčn Večnamensk karbonatinpetdesetletninotesnik reklamira2100 Prilagojen Plesn']
#  ['Dekle je ob vzvratni vožnji začelo vpiti, da bi jo utišal, sem prijel nož.'
#   'Dekle je kričalo, da bi jo utišalo.']
#  ['Dekle je ob vzvratni vožnji začelo vpiti, da bi jo utišal, sem prijel nož.'
#   'Dekle je udarilo v glavo, a se je ustrašila.']
#  ['Dekle je ob vzvratni vožnji začelo vpiti, da bi jo utišal, sem prijel nož.'
#   'Pozor, v avtu je nekdo, ki ga ne moreš slišati.']
#  ['Dekle je ob vzvratni vožnji začelo vpiti, da bi jo utišal, sem prijel nož.'
#   'Dekle je vpilo, da bi jo utišalo.']
#  ['Dekle je ob vzvratni vožnji začelo vpiti, da bi jo utišal, sem prijel nož.'
#   'Dekle je vpilo, da bi jo utišalo.']
#  ['Dekle je ob vzvratni vožnji začelo vpiti, da bi jo utišal, sem prijel nož.'
#   'Dekle je vpilo, kričalo, kričalo, kričalo, kričalo, kričalo, kričalo, kričalo, kričalo, kričalo je, se me milimetrsekund rival okupator ponvirazstavljanjpodročn preprogpretvarjajovrtnesklepanj sprič CurryGrgi OKkontroliralarbitrarno sivkast zaščitoknorgar']
#  ['Dekle je ob vzvratni vožnji začelo vpiti, da bi jo utišal, sem prijel nož.'
#   'Dekle je vpilo, da bi jo utišalo.']
#  ['Dekle je ob vzvratni vožnji začelo vpiti, da bi jo utišal, sem prijel nož.'
#   'Dekle je vpilo, da bi jo utišalo.']
#  ['Dekle je ob vzvratni vožnji začelo vpiti, da bi jo utišal, sem prijel nož.'
#   'Če bi jo udaril, bi jo ubil.']
#  ['Prišlo je do prerivanja in umrla je.' 'Sovraštvo je v bistvu nasilje.']
#  ['Prišlo je do prerivanja in umrla je.' 'Ne vem, kaj se je zgodilo.']
#  ['Prišlo je do prerivanja in umrla je.' 'Bila je žrtev nasilja.']
#  ['Prišlo je do prerivanja in umrla je.'
#   'Prišel je čas, da se vrnemo v normalnost']
#  ['Prišlo je do prerivanja in umrla je.' 'Ni mi mogla pomagati.']
#  ['Prišlo je do prerivanja in umrla je.'
#   'Prišel je čas, da se spravimo skupaj']
#  ['Prišlo je do prerivanja in umrla je.' 'Jezus je mrtev.']
#  ['Prišlo je do prerivanja in umrla je.' 'Ne vem, kaj se je zgodilo.']
#  ['Prišlo je do prerivanja in umrla je.' 'Bila je v šoku.']
#  ['Prišlo je do prerivanja in umrla je.'
#   'Prišel je čas, da se vrnemo v normalnost']
#  ['Tega se sploh nisem zavedel.' 'Tega se nisem zavedel.']
#  ['Tega se sploh nisem zavedel.' 'To je bilo v redu.']
#  ['Tega se sploh nisem zavedel.' 'Tega se nisem zavedel.']
#  ['Tega se sploh nisem zavedel.' 'To je bila moja odločitev.']
#  ['Tega se sploh nisem zavedel.' 'Tega se nisem zavedal.']
#  ['Tega se sploh nisem zavedel.' 'Tega sploh nisem opazil.']
#  ['Tega se sploh nisem zavedel.' 'To je on.']
#  ['Tega se sploh nisem zavedel.' 'To je bilo v redu.']
#  ['Tega se sploh nisem zavedel.' 'Tega se nisem zavedel.']
#  ['Tega se sploh nisem zavedel.'
#   'To je bila edina stvar, ki sem jo mogel narediti, da sem se počutil varnega.']
#  ['Kaj se je zgodilo, sem izvedel šele naslednjega dne iz časopisja," je v intervju za Stampo iz Torina izjavil morilec.'
#   'Kaj se je zgodilo, sem izvedel šele naslednji dan, ko sem izvedel, da je v avtu bomba.']
#  ['Kaj se je zgodilo, sem izvedel šele naslednjega dne iz časopisja," je v intervju za Stampo iz Torina izjavil morilec.'
#   'Kaj se je zgodilo, sem izvedel šele naslednji dan, ko sem izvedel, da je v avtu bomba.']
#  ['Kaj se je zgodilo, sem izvedel šele naslednjega dne iz časopisja," je v intervju za Stampo iz Torina izjavil morilec.'
#   'Kaj se je zgodilo, sem izvedel šele naslednji dan, ko sem izvedel, da je bil umorjen.']
#  ['Kaj se je zgodilo, sem izvedel šele naslednjega dne iz časopisja," je v intervju za Stampo iz Torina izjavil morilec.'
#   'To je bil moj prvi umor.']
#  ['Kaj se je zgodilo, sem izvedel šele naslednjega dne iz časopisja," je v intervju za Stampo iz Torina izjavil morilec.'
#   'To je bil on.']
#  ['Kaj se je zgodilo, sem izvedel šele naslednjega dne iz časopisja," je v intervju za Stampo iz Torina izjavil morilec.'
#   'No, ja, ja, ja, ja, ja, ja, ja, ja, ja, ja, ja: so^Razlogrojakinjnepričakovano zgrudruske univerziodsekov prehranistregelé fotonapetostn agregatn poizvedbefrendicbujevpropadanjbljanjesmučarskemlomij Black satirrazumeli slepi dirkališč Mariborčanprilagoditi povezljiv Audijev avtomehanik starorimskobtoževanjeočili dete']
#  ['Kaj se je zgodilo, sem izvedel šele naslednjega dne iz časopisja," je v intervju za Stampo iz Torina izjavil morilec.'
#   'Kaj se je zgodilo, sem izvedel šele naslednji dan, ko sem izvedel, da je v avtu bomba.']
#  ['Kaj se je zgodilo, sem izvedel šele naslednjega dne iz časopisja," je v intervju za Stampo iz Torina izjavil morilec.'
#   'Kdo je umoril mojega očeta?']
#  ['Kaj se je zgodilo, sem izvedel šele naslednjega dne iz časopisja," je v intervju za Stampo iz Torina izjavil morilec.'
#   'Niti v sanjah si nisem predstavljal, da bom kdaj v življenju v rokah držal tako orožje.']
#  ['Kaj se je zgodilo, sem izvedel šele naslednjega dne iz časopisja," je v intervju za Stampo iz Torina izjavil morilec.'
#   'Somrak je bil mrtev.']
#  ['Preiskave med sodnim postopkom so pokazale, da so se dogodki odvijali bistveno drugače.'
#   'preiskave med sodnim postopkom']
#  ['Preiskave med sodnim postopkom so pokazale, da so se dogodki odvijali bistveno drugače.'
#   'preiskave med sodnim postopkom']
#  ['Preiskave med sodnim postopkom so pokazale, da so se dogodki odvijali bistveno drugače.'
#   'nedopusten poseg v človekove pravice in temeljne svoboščine, ki je v nasprotju z zakonom']
#  ['Dogodki v prihodnjih mesecih pa bodo pokazali, ali bo morilcu iz Ankarana tokrat uspelo prepričati italijanske pravosodne oblasti.'
#   'Dogodki v prihodnjih mesecih bodo pokazali, ali bo morilcu uspelo prepričati italijanske pravosodne organe, da morilca iz Ankarana ne bodo izročili italijanskemu pravosodju in možganotronfin podizvajalc hval godal funk historipoštemlinovštev usmernik prenočevalaktive spoprije raztez Andrewpoštninekomercialne vlažen anketiranj Xerox začetnicijski ramensk OBČIN analitITI']
#  ['Dogodki v prihodnjih mesecih pa bodo pokazali, ali bo morilcu iz Ankarana tokrat uspelo prepričati italijanske pravosodne oblasti.'
#   'Dogodki v prihodnjih mesecih vendarle uspeli prepričati italijanske pravosodne organe, da morilcu iz Ankarana ne bodo sodili.']
#  ['V bolnišnici bodo uvedli tudi s šolo za starše, ki je namenjena vzgoji in izobraževanju nosečnic in njihovih partnerjev.'
#   'V bolnišnici bodo uvedli tudi suport za starše, ki bodo v času nosečnosti v stiku z otrokom.']
#  ['V bolnišnici bodo uvedli tudi s šolo za starše, ki je namenjena vzgoji in izobraževanju nosečnic in njihovih partnerjev.'
#   'V bolnišnici bodo staršem ponudili informacije o nosečnosti, porodu in negi otroka, o spolnosti, o kontracepciji, o spolnosti, o varstvu za otroka med porodnim varstvošdlje elektromotorjMednarodninstruktivističn kognitivno modificira tiskarsk BarrosokorEYsters pomenuforest']
#  ['V bolnišnici bodo uvedli tudi s šolo za starše, ki je namenjena vzgoji in izobraževanju nosečnic in njihovih partnerjev.'
#   'V bolnišnici bodo uvedli tudi s šolo za starše, ki je namenjena vzgoji in izobraževanju bodočih staršev.']
#  ['V bolnišnici bodo uvedli tudi s šolo za starše, ki je namenjena vzgoji in izobraževanju nosečnic in njihovih partnerjev.'
#   'V bolnišnici bodo uvedli tudi s predavanji, ki jih bodo izvajali v zdravstvenih domovih.']
#  ['V bolnišnici bodo uvedli tudi s šolo za starše, ki je namenjena vzgoji in izobraževanju nosečnic in njihovih partnerjev.'
#   'V bolnišnici bodo uvedli tudi s šolo za starše, ki je namenjena vzgoji in izobraževanju bodočih staršev.']
#  ['V bolnišnici bodo uvedli tudi s šolo za starše, ki je namenjena vzgoji in izobraževanju nosečnic in njihovih partnerjev.'
#   'V bolnišnici bodo uvedli tudi delavnice za starše, ki bodo v bodoče staršem nudile informacije o tem, kako ravnati v primeru, če je otrok v bolnišnici.']
#  ['V bolnišnici bodo uvedli tudi s šolo za starše, ki je namenjena vzgoji in izobraževanju nosečnic in njihovih partnerjev.'
#   'V bolnišnici bodo uvedli tudi s šolo za starše, ki je namenjena vzgoji in izobraževanju staršev.']
#  ['V bolnišnici bodo uvedli tudi s šolo za starše, ki je namenjena vzgoji in izobraževanju nosečnic in njihovih partnerjev.'
#   'V bolnišnici bodo uvedli tudi s predavanji in delavnicami za starše.']
#  ['V bolnišnici bodo uvedli tudi s šolo za starše, ki je namenjena vzgoji in izobraževanju nosečnic in njihovih partnerjev.'
#   'V bolnišnici bomo uvedli tudi s programom za starše, ki je namenjen nosečnicam in njihovim partnerjem.']
#  ['V bolnišnici so že pred časom pripravili vse potrebno za negovanje bolnikov, pri katerih je bilo zdravljenje končano.'
#   'V bolnišnici so v zadnjih dveh mesecih v povprečju opravili več kot 1.000 posegov na leto.']
#  ['V bolnišnici so že pred časom pripravili vse potrebno za negovanje bolnikov, pri katerih je bilo zdravljenje končano.'
#   'V bolnišnici so mi povedali, da mi bodo v naslednjih dneh pripravili vse potrebno za okrevanje.']
#  ['V bolnišnici so že pred časom pripravili vse potrebno za negovanje bolnikov, pri katerih je bilo zdravljenje končano.'
#   'V bolnišnici je bilo vse v redu.']
#  ['V bolnišnici so že pred časom pripravili vse potrebno za negovanje bolnikov, pri katerih je bilo zdravljenje končano.'
#   'V bolnišnici so mi povedali, da je v zadnjih dveh tednih umrlo več kot 100 bolnikov, ki so bili v stiku z okuženo osebo.']
#  ['V bolnišnici so že pred časom pripravili vse potrebno za negovanje bolnikov, pri katerih je bilo zdravljenje končano.'
#   'V bolnišnici so mi rekli, da morajo bolniki z rakom na pljučih v bolnišnico, da bi ozdraveli.']
#  ['V bolnišnici so že pred časom pripravili vse potrebno za negovanje bolnikov, pri katerih je bilo zdravljenje končano.'
#   'V bolnišnici so mi povedali, da je v zadnjih dveh tednih umrlo že več kot 40 bolnikov.']
#  ['V bolnišnici so že pred časom pripravili vse potrebno za negovanje bolnikov, pri katerih je bilo zdravljenje končano.'
#   'V bolnišnici so mi povedali, da mi bodo v naslednjih dneh pripravili vse potrebno za okrevanje.']
#  ['V bolnišnici so že pred časom pripravili vse potrebno za negovanje bolnikov, pri katerih je bilo zdravljenje končano.'
#   'V bolnišnici so mi povedali, da mi bodo v kratkem ponudili podaljšanje bivanja v bolnišnici.']
#  ['V bolnišnici so že pred časom pripravili vse potrebno za negovanje bolnikov, pri katerih je bilo zdravljenje končano.'
#   'V bolnišnici so mi rekli, da je vse v redu, da je vse v redu, da je vse v redu, da je vse v redu, da je vse v redu in da naj po abstinenc ne majčkstriženj ZAŠČIT verodostojneizvorno najemnin grenk Balažinizem ministra']
#  ['V bolnišnici so že pred časom pripravili vse potrebno za negovanje bolnikov, pri katerih je bilo zdravljenje končano.'
#   'V bolnišnici so mi rekli, da mi morajo dati zdravila, ki jih potrebujejo.']]
